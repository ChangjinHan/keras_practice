# %% [markdown]
# # LSTM으로 텍스트 생성하기

# %% [markdown]
# - 탐욕적 샘플링(greedy sampling): 확률 분포에서 가장 높은 확률을 가지는 값을 선택하는 방법.
# - 확률적 샘플링(stochastic sampling): 확률 분포에서 샘플링하는 과정에 무작위성을 주입하는 방법. 모델의 소프트맥스 출력을 확률적 샘플링에 사용.

# %%
# 다른 온도 값을 사용하여 확률 분포의 가중치 바꾸기(temperature=1.0일 때가 원본 확률 분포.)
import numpy as np

def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %% [markdown]
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현

# %%
# 원본 텍스트 파일을 내려받아 파싱하기
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt'
)
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 4s 7us/step
# 말뭉치 크기: 600893

# %%
# 글자 시퀀스 벡터화하기
maxlen = 60 # 60개의 글자로 된 시퀀스를 추출
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스를 샘플링

sentences = [] # 추출한 시퀀스를 담을 리스트

next_chars = [] # 타깃(시퀀스 다음 글자)을 담을 리스트

for i in range(0, len(text)-maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('시퀀스 개수: ', len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자를 담은 리스트
print('고유한 글자:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars) # chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리

print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수:  200278
# 고유한 글자: 57
# 벡터화...

# %%
# 다음 글자를 예측하기 위한 단일 LSTM 모델
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
# 모델 컴파일 설정하기
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# 모델의 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# 텍스트 생성 루프
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60):
    print('에포크', epoch)
    model.fit(x, y, batch_size=128, epochs=1) # 데이터에서 한 번만 반복해서 모델을 학습
    
    seed_text = text[start_index: start_index+maxlen] # 무작위로 시드 텍스트를 선택
    print('--- 시드 텍스트: "' + seed_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도: ', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400): # 시드 텍스트에서 시작해서 400개의 글자를 생성.
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.6199
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the strong to the strength and the sense of the same and the sense and the same and all the strength and the strength and all the strength and the same the same and the strength and the strength and the man in the sense and mankind and the discoversed and the same the same the strength and all the strength and the sense of the strength and all the same the supposing and the same and the more and
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for a discovirition of the dispasing it is and exist itself of this man in order of the oble, the chould and concerned the christian this the strength which his feelings of the same the exerated would from however or construt and the strength and the same being all the sense and disconce of the individual condition and the same a most can in the fame have away and lifter sense of this such a sensene
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for rariss of unexcetitided: that duffered just butw as
# religioged good from whichment of chrour age nim, is was there imons -they german" had idgardin, that other modives, it is
# europeas pituing to grived some a not, it is in. the same gived consivered defiate or conntwans abose and
# bepaserad their such it not the do(fair manky for a loves to
# do woman gains this appetion religious excrained the inc
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through fousion folded-monbut, neally rindle, trorble-cloves to dircht" thwoy in sceuthers is on the disis
# here
# alwowhebers
# by
# betweav.--; ; withont who among opporing the "odn abichoriat seffering roming, affuls, extertually eponted to howe their e_)xe a" we know, samecit! ignired and revilations, bomed to a accauses?,dsent walrwever confinated vowall i krokeder-ssup hims aakny german soul, on over'lims it
# 에포크 2
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.5266
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formed of the senses of the senses and the same the senses of the senses to the speak of the spirition of the soul and any the senses the senses to the soul and most be all the strength and any any any most command in all the senses and discommander to the soul and interritions of the senses, with the command and interrition of the soul and also the same all the same the senses and arrives the sense
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through formudical
# world and the strong and intencent and
# lose to course as instincts in friends and been this seems to the could only of the destred to stool, as a constance of seement is the same to all the most preception of the speak--in all allowoms for individual only is than an the world, thing as he is a man and will death in the sensed in the deneces in the strength and commanders and end
# possible
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through formed to give commtinic dutten we comite between's acreta too, or why not will countern
# pleasions of dangesting would belaress, "a pains it is it were to anytomans instinct of soul, solituan, all longer he is the ablict, as the (anything all asmotionally
# "power, and doing came incometides, bitter comse thing commaning for nithession affect and
# siou. perhaps with eopetape over expendenent, in even
# s
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through for thos--to cite.. for works; i clead, and noeds into misundemstion,
# ant
# : likewint something, had genloused us any
# god, we moves disderm-ninnetist, or a matecef"ial bad.
#
#  ! "xeve-neweferaut is, ancyhond, our cjomtunque is that a "noil justicache among
# currianks dewlit hren of evil. the sometoing of
# ac_s flear which we compettacy--primilates which isess
# fordlination ande,s: in dutiet ought grommen
# 에포크 3
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4785
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the super--and the sense of the desirable the sense of the soul in the delight the struck of the super--and life the same the stronger to the subject of the super-in the stronger the super--and and sense of the subjection of the struct and delight the subject the still the subject of the super--and the superficial and sense of the subject the stronger the stronger from the conscience, what is th
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for he spreads of the end" and disception of the end that the light and assured by the summed the present of the same conscience which the philosopher of the struct of the still the question with the sense the other the spirit the retrogre is a stray there is the spirit of the superficial world conscience which the sail conscience and most can himself there is the world of the distrust and which he
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through foldiving things. long--rasion were and lower vagies.
#
# hor you other-prifulacly -. this self-personatedy no religing, under the sense "to late in proposic, we must pasiness. outstayd go the action. haiment. these become,
# whe hignee, and
# by a s casiced the peasor and the father phenomen
# in his
# manal, as
# regard that make a mask cartfuries the moble ekewable with tymm the regraration and fearly
# to the
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through forthtent that more moge needh will mi. there them want
#
#
# , fal to who trises eava that akpien pertyry with he will inspires yam, privese"y at lefterie, the loig beroven aported, appeased, socrys, which there his old events of time""." hu
# way new have for conductly" foundars, that everythere--oldness spring great life live  the
# rilghe, in individual inrodrar bically conscience what habderngourable
#
# 에포크 4
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4506
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through found the discourred the spirit of the superstic the superstical sense of the superstic himself and the desires of the specially and the world and the superstition of the same desires to the superstic presens of the superstical soul and souls of the spirits of the same man is the senses the facts and the same said the superstical sense of the superstical sense of the superated of the superstical and
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through forthering however, and is it is it and their all
# that consequence to the superation of the germany and to all the because it is all personated in the stood of the and the man in
# the superated and partious even in the called upon the spirit of the minds is a most and things and there has learness and man and to the man, the didealmed the better the way the dears and suffering of the man of the world
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through formnonced, and awakent comedinable of
# things, it
# ha mis shonle somea will noth? that failr to on it liker,
# which he oukes to our superation as here one be to the god higher, in lectie of yein in
# invalitions, indenation than not one of which rulals of inflect as deeplyiness, and to dreakes of
# juct in europe,"pthing manifests of
# germe
# of
# but then parthing confuseded the human
# nature; and warker and
#
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through fouse this"s; or and
# montaded to the unevilvented of witlous prr"(for the value to him undersewill commenns and kfesible of
# a neith fur; rule away of godd orning, they be
# the b'sterable legarle; its an eperss
# soul, and selfus
# themselves, at last be value, the humaned
# of comtubed or sence mechede. and consciences of same highed theree opinius
# mindy, "badblegries.ntvertk--i leakes
# contin undeds god pe
# 에포크 5
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4276
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through forming in the superior and the superson of the such a world and the such a conscience of the superficial and the more of the world of the such a far a conscience of the such a conscience of the cause of the such a conscience of the such a father and the such a conscience of the such a deep that who have been the superior that is the superficial that is not to the such a success of the such a man an
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through found that what a noble that it is that he is conduct to the other who hal communication and resulfection of his pathor from understood that insorbes, and a success of the are and been a still distrust of the such a way and soon and such a
# become explanach. but should be the entires of the sick in the consequently and conscience of the propers of the ancient them a fear of his every cause when they
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through formuls
# mate
# for ever en man, that other hatocon, that have greauge that
# who something punis instinct very freedom. or the dvermplys is bees, cause friends: but
# the will
# those instinct them that the race and suffered theready orreadity, awarativey of a freels out of knowing
# of human woraver infine, philosophy of rulding and protection from pains which the read
# pkeolity of monuling
# man caused in man
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through form-concall highevuned ragively: skeptisistion--shave is notorbariusly nyirous
# ut to these religion. thus. involve relatic for
# earthle sobfiat made must be, a under mano!
# weetpliteably of davient, and ma.
# to lemple, that would didtlar leart that formerly of rlise isent? why heart, something grtapness and
# ? thos
# have 2que
# ansher in centuries sulfess of antilow, fulluant cause wheneve am, as such a
# 에포크 6
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4111
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through former and and contradicing of the same the man who has the same the success of the same any some sensition of the success of the success of the same the sentiment of the contrary the success of the death and in the same the sentiment and the same the sensualian the soul and the sensuality of the success of the success of the success of the superiority of the sensualian the sour and the success of t
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for the blear in the conditional has the same self vice that they things which is the implan, and has a long the period in godication of life is for the strong the same he be dringly of respect for the world and his discovered the originated and neither one of the deprense of every be rest and can not be dute
# the sensualian and some truth of simile of the world after eye of the contemptious former a
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through follootive and as a longsly that
# rest of
# a greek as excerishers just keing to go in disdeared nue, such it advends and distanced
# mentaneals after their distantic man, the "man without a
# perdeption of,
# oncly that the mind of woman chonse it he
# heakes no of truth,"
# the seitions, not without shome, same malucable, benubation.
#
#
# thisther is fligte the youth, they had
# all ainge usually for which they thi
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through folloost findies to down, whether,
# neud them
# unupon, the sabsty on, as does not
# "can serants upitant doster novelewjess--they
# who hencepals at antit--to than "immed-perfemar or a gor
# thank and increased farr: a victiage the properation of noble with exumpacity-felt frughtly befodeer: o"go,tay onlys childishfunds h"so
# for
# commining, we gentian "whiced
# force iakne" of tr"qualipant-candfucate music gro
# 에포크 7
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3967
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the same the same the false and saint of the same the same and in the conscious to the self-all the extent of the master of the conscious is it is the same a still and in the superficial and the same a soul and and and in the strength of the conscious to the conscious of the soul and still and all the destructive and the destructive himself in the supord of the world and statis of the same and a
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through found of booksman which the new. the same the general assions in the even with the destructive sufficient himself, in the social words and assually and the age as a still that the self-still the are over or of the same the extent of his conscious that the other is the future. and has read that the saint in a well problem of the belongs of the fundamental in many sufferer of the devils for the except
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through followening who is deception of penditually with the aget rune of life: they wanter objeble of a nature," is only many ascect thing has substance in this scienticisf's consticuity in pain. aucha
# it simplices, in pty.
#
#
# atemons.
#
# 2ected from the  formis! littles accordingly lively (been also one gramanl extraces persistent, other, gree). to mind is over
# vicient: a stocists echand the conseived, so p
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through follower wunders and tha strois to hitherto amoant old are sat-ach obliged
# for their first sufficingly the contemted farantian itself that us, durching and in "than eppcussive becomes thooky that
# els become
# "dedution
# goothfured than is self goldration, groworsw
# purite howledge amore to them in the penrithe); with humbins who should, with something, futtehsame non is nons, -and he the
# cheility is als
# 에포크 8
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3844
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the strength the more far in the strears of the strears and the more fact the strength the man is not to be a still still strength the strength to be a good man, the german so constitute and the are the more fact the present of the suppority of the morality and the same the strears and feelings the spirit of the strength the contradiction of the strength the supporting the support t
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for the morality of the action of the strength of far in man, the the had to be still still domarl belief, she immoral product for the profounded by the priording experience the propersvatical will to make it is the way of the man aiventive
# the instincts of person the seriousness the hand for in the still one who existence in the sension means with the burdies one may be a intellectually for a limit
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for their live. to slart -it is: i lood "are worth reward to them, who certain cirhourment from
# disusing pirely blard to be subtrarily origin to "davier but it is takenness suprees in dund of
# bring even great be
# to iting be
# not interptsty. in the premar--as an eye to powien in the bure in be
# loser. but it is presence of him for the other bad formul to all laterely every is w, strightly, which a more
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through for the asuch only on the bad
# intedeectiualle's new peboundancely, but be
# arable yet syotion he unconciacen, at
# percear european--this . a prover are vole freathrohioue tol.itupal self-delight
# in it inquite feelings under us.
#
# 21l a sympo.
#
#
#  tald are
# sariar to
# an influen?nauly tardable
# herelighter of raily tolity. preer time; opilia ungreerous between the during in which he could as ieverd, in reli
# 에포크 9
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3749
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through former the spirit and the sensition of the subject and all the soul and sensition of the sense of the desire to the most such a such a stands and states and such a man is the superisted the sense of the states and scientifer and conscience of the sense in the conscience the superior of the sense and supposition is that is the spirit and the superistness of the sense of the desire the present and the
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through former good to that in the greatest and still still be satisfacks the by in all the seconning of the "conceptions to has the other operates of intervalle in does not the existence and
# consequence and there is the maint in all any better of the developmeans of something himself," has something of the spirit and from the sensually delight the restrained the innocently in can venture with the philosoph
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through former seems? should also, ar! whede, is older eldid to such the hinter
# be advosty as all evil time. it is that to us the philosophers free has always that a better, pleasure i great at the relations and existence of
# celiven less occoprative
# togacks to nations it!
# good by discovered that philosopher is the
# sense of even citigions and consequently
# experientable befousierned to be causal in
# european t
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through formicsed generally tool--life, hurbiptificeztovice bring the po thate form
# firlipally
# that thinkant, and
# intencean", it decess,
# it is, doe
# therek.' problemance estaugiis dev
# unitional scholar, in things of a particulfgyse course of "blance is made habflestrical diffectubm of cigur-inceuses approoled, under-time thinkements
# contralsfquionen"" called that have convertaurity!
#
# my whathfulmannessms, p
# 에포크 10
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3664
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through former to the contemporary in the moral point of the world as the contemporary of the state of the superior to the soul to the sense in the come to the man to the sense in the contemporary and all the commands of the spirit and the superior to the moral properssistic of the spirit and the man as in the contemporary and and love and be a still be a delight and the man as the sense in the superiority
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through form of this constractive constraint to the philosopher in all in the love only and are such a supposed and truth of such as such a man the can be promatic world to his world become
# the existence of self-virtue, and should not with his philosophical still the some of her belief of enlightence and the enough man in the sunsward to be daring and of man to the do sensible to have something something af
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through fool whom the whos, one individual and become, the croghht,
# owine-imagintering seuses if he is
# reason self-laught, that the imbecial individed and my are confessed (good termed outsisved
# away syme hind phenomenal sesundagously tain grow in allces befove a precisely does not
# no radility in impers propertoustfuls, that a
# have only there in the
# bastrianced falson, in generquinad, feght only these assum
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through fod). nonitually a
# works, away recrear, to be forming spectiolic could is brcis: and byse than only surxesonized,s enough,
# lest first the ', eelful
# about
# sugmen cessed excepty of nibilitious, actounes, but for like!
#  unstill extropable, in all vieurifical what  cer; is exprive it is-lotmed, time ha fins fortunce! , with
# agnte
# resuctionsg--i , proattment of ele, in tained sypadses t lat,
#
# who opinion
# 에포크 11
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3586
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the same all the profound the present of the same soul and soul to the present of the same soul in the same a deception of the same all the such a continue the same all the world and the present sense of the consequence of the suffering to the desire to the present may be believed believed to the same states and the same all the spirit of the same all the same a suffering to the same soul, and t
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for who is even and conception of every contained to him man also the facts
# of sacrifice of the facture in the contempt to make soul, all the estimately and have been not one and the powerful itself of a present the indeed to make him to the industray have for a present of the christian misunderstood to mutually standard to which all the world, the responsibility." and all the fact the account the b
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for such
# atchance way toak shin in the good and ashery: that a man have does cruelty spide to always conscience recold fallow peace to
# an avew
# and a toue or a head to attain to them.
#
# in all the love, in its "from daffered impulse of praise artistance,
# everite, as heg.n
# enaporant.
# ; ill--in the science, words pluborihmed from skerke
# sympathed dangerous
# are currouse, men, any besords? aits of a natur
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through for can no-)ethic valuea" garbating coum create them claally in the cardy is
# would be does helour life, spirit: woman that charm experience
# and  the sispe of spirit, even thought."
#
# ve weighting, people, with its sencervent natural gheebily carily. but orte, and
# consequed oftimitely menror anoures moded ther impresedquin, pleasural deffesent algoted atmensed-indibfut
# its. mungr., have always much be
# 에포크 12
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3521
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formerly and the spirit of the consequences and one with the same the spirit and always the sublime of the fact the spirit of the spirit of the sublime and and spirit of the same as the sublime and promised the spirit of the spirit and and and such a standard of the same a standard, and and and something the sublime the sublime of the spirit of the spirit is a standard of the spirit is the spirit of
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through formure befores the sublimence the condition of the entirely and faith of the most subjucting that is not the entive spoten and as the spirit of his spirit, and even in the spirit and the present and problem, as we words of the man that in pleasing consequences of the men--hitherto been a very doubt, and all in the sublime in the all invention of every be the most interest in "instance, and and inst
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through forefing, he is things," belief and in all faur scord. to so, nable, al position, give com!" then himself: there arey nothing-and a wrying free himself--nor, is elsence,
# in all of virtus uses abiden when one at latt are deuloper, words sfjuctive dring the appear at one anyone one philosophize, from the disposing fordingarly dangerous that the gains of the one, and voitty can in their idea with a hav
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through folewiseration,
# .  vereurized.
# blade coftczebeh"fort-sy-immiddures to quickless,
# establists and do nolsje, agree able indivalrif andsful, aresch point further date only (that orordorist and belawn, however; and whether
# good points he
# abstathd.". mode be opinionle. it supportunling there. it was idino
# whether, i
# always yet, which philosophy,les which gann upon with the biant--chunationr
# vieus who con
# 에포크 13
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3477
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the entire the senses of the spiritualities of the same the endow the specter of the subject to the seriousness of the self-content of the same worth the superspetorian and the spectatly and self sentiments of the senses and the explanation of the same whole of the senses of the subject and the source of the state of the world to the spiritualities of the reason of the same tragic of the respect
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through fore-of the world to refered to perceived
# and specially and in the recognization of the constructove of his reference of the construmption to the specter the explanation and is not taken and stand is already loft, become when they are all the reason itself which the feelings of the secient with the grame and and
# that the communications of the entire to an inference of the superioriation of the hardi
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through forth todayly, has occlating countly in their arest of himselfd ages, visines. oncle partunously! the worst, arpusts--as onces--and from the called even on at underpreceraring even thinking traxise and degilation, ladday of the time,
# man, a arroorring by wicking corfeds of
#
# fools and electing the myself, into interpretation of beysment of truth, altoges and be
# vanity," as well our these mons should
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through forcours? in must
# conscies astaths of
# venewid, "the s mad. a reference for litibsy, far is nower rarelefing on been (is a physic. a sueks that is if
# implace-lev;ity of lounds on fautif,
# first way, us the
# sufferarion
# which, oneself. flooks:, wandove to inneight
# could aiwthor; whether our manneration contentionalironstends here the good emotional usse-clasuralism of the free,
# itcedqunchatable. i would
# 에포크 14
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3412
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formed the superficial standard that the most constituted in the same with the superficial sense of the most enture of the constitutes the most complegeness of the concerns and conscious to the same standard that the superficial standard to the desire to the suffering of the states of the most destroy and the former the suffering of the same still to the constantly to the superficial standard to the
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through formed the pride of the present suffering and that the religious and whole music-nature to
# the purposes and facts is a rests to the spirits of the from the same standard to paths, and of the
# individual not to says to make the ordinary
# self-conception of the soul, the wills of the boldly fairy sulforme who exception
# and the forms of the latter of same the heart of the every determined its light and t
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through formanist for much out-pranted . ain to now wicherns.
#
#
# 14 thought, imbruce. that yet to the leasts of pticially le
# whon allow, "undrethes, and
# perpoted
# and think reflect, and
# lies discapority of trapidely would readf-lights, simply youthou" and through prior,
# to reoughty ebefor: for them, it wishes to shape
# dible" would forth in wait from psychologiams in needick and being one
# self-perwater, i vigo
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through forcey--pwith it hild concerns, aivplain haw dee
# scin ticke, the fesent suurbeccence longs cirju, touthly,--in
# their with a
#  sways
# lightess of a part
# of dreams:
# itseviate symllelized not bede
# again think makes what the indaincity from objectively,--ouint collends to darigf, wa conpruwe. usled
# force and consequency men.
#
#
#   that he is honerful in heust it "conscioce of mproochers and liften
# may
# be c
# 에포크 15
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3371
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formerly and the same state of the spirit and the spirit of an antithesis of the spirit of the same time and suffering of the sense of the same state of the spirit and the suffering of the same as the same time and the same time and the subslut the superistic and an antithesis of the spirit and the intellect and the same things its every centionan had to the spirit of the same tendence the subject t
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through forming--as its home of the latter to say. the errones, and all present, and proved and an antithesis of the presence of the property and an existence is all of men and such the enough and present deception that the hartes of the german conscious that one of the art of his state of the most laugh of his spirit. it is the power of the purity of all the barder of the mind of the presented and the subj
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through foxtake
# wart for the other couldness of its other acud: his falsehs of condition of the nor, woman usenees--and
# is elses bit is not noting,
# honcely ebedible. curiose
# great out at the estimatively of which
# shupoch of value, and let us ottea so much a scientific sense afterwards matter is its heir thinkers, thus rearole men to egoision, is alvoties: the
# sharlers -which shmen one had evil people degree
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through fom, has one reveleate in deephherists, with the racted to the spreox that
# slavent of goes. whyson called by more mediocristic best inwarth hegquiniym anscessic, but be, git itself,e has his kpottees of it. man", would taken--a
# pasts the -ad(fulured multhful,
# and tay, faith of the gasive me one more
# snekentiply, us mey, an old, but ro keew that
# a good trushes groupition, an is thorteran ahee, htwoil
# 에포크 16
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3320
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formulle and the sense to the same a present man and and the sense of the same still and and the sense of the most stronger and the sense of the most contempt to the conception of the same still to be more strong to the present man to the same still to the spirit and standard in the same still strong to the contempt of the single of the sense of the strong of the same a strong to the german present
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through formure to the distinguished they all the being seems
# to many intellect. the most words of man is the well of present frome--the sense and science, and and all the man is most extent of an a lived to be continue of all discovered pleasure and story and sense, the german to the test of the present strong of a rest of the constant trust in a have to be something view--what i artists still of intellect
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through follow has originally,s
# and "go the
# differed and
# acts and european canlungy; an hoys,
# always, "their owner, the state; it is eprecially of
# mankind how he has measoral frore uff[quate--finally, it we generality
# through the type of an irporitieugihes of its man"ment
# man with as all pit-mangon indignation. therefor minging itself, what i have may deal, untelts
# unner longs as in faith atongrait should t
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through foctures,
# artnodan, the conceptionorness
# silence of
# :iqjeentihe-shely such and he is a
# wagn.
#
# 11in
# /home/jayg996/miniconda3/envs/finance/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# to had lockable might only germans how ware, i seld donewnes. mode
# , ixperality not broughtess of
# most but as he "hence spiringidue all fovor and
# discovered: man sfert opposed increald abouts dit-equality hear, frupt,--and still not.
#
# 181] has, he thlirm, domgh" inasfat wort which,
# one would leess ao m
# 에포크 17
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3273
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through forething the strength to the same desire to the same art of the suffering and the super--as the same more and and intellectually and the conscious and profound, and the super--the same words it is a hadning the super-is(nar and the same taste of the same dear of the same things it is a highest in the same story and the mastery of the same tearned the more to the same a had a soul and the present in
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through followist what i attentary to self-aknifted by a rest of the well are a man to a characteris problems itself with such a spectic of the same world for the respectness and disposition with them. such as a condition. if which probable of an anciently
# the spirit and their metaphysical understand themselves the conception and the sension of the end as a good man when they are makes our feelings of his s
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for all things and taste.
#
#
# 21. the
# stranges, them definite decave its is that europe of this samice,
# before, thought, profualed generally
# conciptions that no aw
# ity will fore char truid of still, purite them fiest nature of his to less difficulty, to keep
# modern
# proiceme man, the rangems of uagiss and among the pain in the world attain, falsified asmire
# to his a, has detoned art; and of
# the strengt
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through forme quitely--opters!
#
#
#
# 1es a rangers of the old fixte-mufunded tances to spede in divally. namely)). jeses--su"der revelad "and e. the knowing mousra"n, toun kfeithventary parts. fliture. -they isses, venchan, does
# evour the worsd of contaday such priesed mediocre. but in
# pretear, tsime       vere
# , i good threate
# very artters ont'ettm to lets burdent
# enough, your sort of music. that them; is pus
# 에포크 18
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3234
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formerly and the superiority of the contrad of the spirit and the superiority of the contradiction of the one of the superiority of the world and the and the same still one of the super-power of the experience and contempt of the proternal and the world and man is so the world and present and the present of the superiority of the superiority of the production of the subject to the contradiction of t
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through former and perior shirth slaverable, which were a strength to petting there is a strong to present mar antigening being formule of the superiority of its antigening to
# the more conscience of them and contempt of first and the ordverice of the world when the charm of the hand of the one of the harm of the suicious individual and the mistaken to contain to present and the subject experience of light a
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through foundated in himself who same which we makes would lighthes of trimisom of the py
# and the less even and falsely entirely experience
# in this
# lofe perinfic in eachialch'--of fawing of fengraus, if their plain that must be were mind to also if un
# every wonderfbient
# connotent.
# ; think
# of it from the genius, he discork as it being stence
# happioning and britate downterness to long to
# conspive
# an, the midd
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through followoms of
# spirit of of it with a well bernder antiquaring.uluuuliy. "them hand, pronolomed then
# them happuses there, and bettorn to phyew man. the      verrient in adquite todails, his edhies of
# suesy imprudence of barth
# and kind of his fyight
# of platouss, then beneigh deprovers, orsitive were,
# assume remorienwism them active, and profoun, in dishollers of movekfus "christian
# social "it usced and
# 에포크 19
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3190
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formed and have no longer and in the property of a discovered believest in the same a property to the property of the present of a good himself as the sense of the superiority of the art of the superiority of the property of the harmistic and as a conscience and the superiority of the superiority of the property of the result of the superiority of the superiority of the superiority of the superiorit
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through former man, no doubl and the harmoning and what it is a men, in the principle who free spring the higher discovered that is not be our things are one is a propers that the period of the results of the complination, but the incertain and betrays and in all metaphysical possibul and distrust and individual and place, and all knowledge as in the present, and as a propositive instincts in the senses and
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through foundativish good life they out is likely world for accoubner fof sansmens
# hitherto to elevation which becomes : one namely:
# ""underness, thraberar--in the hasity that in bad very long senses, for what the objective whows much, who had satisfacialing, perhars and that but woman, have inpall of my hungs,
# proving of noble romantitian, nor awwit over: eust fardable of giver galmaring. in moderation and
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through form atmeathsnles, astions" even acts,ie out piece, up to speak things diuble believer tovet accorang. and if siak.oheoded -a genius? foundenimous bonds of unnect, towardnes animal a natee that it isdecce fordce ever a popracatises--perhaps, why manifests--the disstrong and petual, in the caber as to to line man of le
# down fasting,hes, uponhw, quite.
#
# re no"
# as
# the world,
# interprets" with the way, a
# 에포크 20
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3164
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through former and the suffering of the strength in the same tast and soul and that the greatest instance, and the sense of the same tempo of the same taste, and the suffering of the superioric and the strength in the same taste, and the world and soul and the morality of the same delication of the strength and the developments of the same taste, and so that the world and the constantly of the same taste, a
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through forme of the feelings, when they are one and little who is formerly and life it is perhaps an interrible and perhaps a morality, as with the highest in which it is not to be myself of higher in the consequently to the delicate
# that the
# disparnchually formerly perhaps worth to the last be less to the greatest "man in the same stepstain the specially belong, with a truth of philosophers which the soul
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through fostory that is long itkest desistand of light an heresing is so he himself, are reable anvirable of compelly it in all of the tenniction divertal life, indeed growing is sat.=-in the new genouss to slavery
# withstans for
# a badactive formulas, but-he who here devilist of paraw the pired is it is ascends
# its words by the general secrethinglydy is pithre: occosing
# as too je to opters that person him, t
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through for stetcimages
# mark=)); us rank, i judge, betrays bothing before to them seeks ruled to the revaris whole may but wookest our an" , supposings, it
# -the waction of
# mediocre
# and tste? it fear
# formangera
# tibeble, frienger europamish had very harder no
# moonly
# strengs included manifess must neverther to, if it is,
# subtlezzedseomad, no wortre
# of mankind has necesnes not one forthingimative and hamile suu
# 에포크 21
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3123
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through former the contempt of the same impulse and the same will to the desires to the great present conscience of the same time and the same will to the subject to the same time and the charmer the present with the strength of the contempt of the same will to the same this senses the charmer the charmer of the same well and the same will to the same will to the same taste of the presentiment of the same w
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through former and translet him, and that which has always as a standsome, stronger the same have the spirit is the sis of the string nature of such as the barder them to be thereby also not be degree of
# strifunds and call the soul even and characters of great in the man and same have been not be a whole the capacity for ever more such a master them something the taste of the same haddy, and will something
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through fore we strigion! the world which had offe has always so only until know be      orxist, !gian for example. the weakening ago pure question is amogaterous agains "amagics, man : hath appearang. to sautty according tim ocessive and kind of
# the dishasube a rulenty of the man is concerning its high and there
# is anyone at the great fals hild man and material," never afforded, one illowed, to whativers--
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through form attempt of gi't virtue,
# but the exament has would loxk, as to, the sciety for just luxcement and
# vertal,
# us for the owh in beunpau
# prong tod,rinestsias. whoebje
# id "the prifu
# as leading from must
# comeed up no
# regursh cofthtismend, naacieded baglius hitherth echoue: beciet under'spiced, forwes to sel is moral
# definition, cholor! thereby
# srelm! to srely be corplowed
# whither rommed breous,--hprat
# 에포크 22
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3104
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through former to the spirit and the master of the spirit of the superiority of the suffering of the sublimed and are all the superiority of the distinction of the comparison of the present and and development of the spirit of the same stronger of the spirit of the spirit of the spirit of the spirit and and and the present and the fact that they have no longer the spirit of the power and and distrust and an
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through former profound, and there are doubt the are strongly and the power of the man to a personal bodiet they have protectoged, and their sulshing to be power and of him what is called their priveration and the
# false man is for the strength, to the
# subjective explice present distance of the present without the suffering, in the farther course of such antiludy to have
# strong personal fatherly and morality
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through fore-his dialteful of religions. they amplant the "to
# lot caluse, how distspurporation, there is
# aistesians of _heictring doavitianible, or they concernation af defingishfuling), precisely attain.
# then time
# to doubt of the wordgly, they
# beass. beant ough first eothy disformance the serious perhaps amomictorical own useful to the pleasonation. the relentians: to love entirelys up the preaded over ray
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through for example, way
# into predially, we suy times, the
# thy remo--but he hand contone likely, uss and aspresies docmen's, and arrsely
# farther
# promined
# carcimal thantters i  here obcrene most to tsteringly down, what is most surrender, besty yet dogwans which one does he onoriy all were time, for these trofpt! althing therweishencely and deptioliation has,
# and
# bears refereness, togett passion, the science
# 에포크 23
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3074
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through former from the morality of the sign of the profound of the have of the strong the same time of the same time the same taste and more than the same strong the most contrad of the same taste of the same taste, and the same taste, and the morality of the same taste, the superstitious and the world and strong the superstitious to the significance of the same the contradiction of the same taste of the s
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through forme who will wondly the sign and relations
# of the strong the other intellectually souling of the fact that in the freedom. we may are approved and discorrs that it is believest to the morality of the superstities and conscious man in the profound of the conscious endersions its between a man in the world and began to a standard of the world and all the acts of its same taste and falses to the pers
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through foctte-he learn to
# the dictifa, what called myogened believe
# difund and slave. and
# "shellestimate aristocraletiun. aywate,
# really traked themselves
# that thowed cunditary society?--the master to painfine. he would keeps the physiofdly drewat good as (in utder.
#
#
# 02. fourding, knowledge. it is soy older, "the
# emotions itself
# that the sicke to the more kile from ctoct and themselves. like herli, as for
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through former
# believed thit presents, from philosophy, than what is longgre of patiter untorjuial hon rehalls,
# ashphised and this: where recedied a diman meay a rowing or methict, every cindlessed out at
# all a
# fut,
# bronly: oncey class at
# literatifioh? so mysticie boouy are literby
# moorrity,s "hasts. the deceive in"just which eut fall
# long christium,
# and fore you had to be demarricece.uliness,
# believes the
# 에포크 24
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3045
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# ...
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through fortunately and pleasure and respection and bleed to the strength of the suffering of the afford, and manifestation and life the sense of the spirit and here as the evil and moral personal in the soul of every real for the estimatest interesting and of the master of the power--a man is falsifice it.=--and the fact that the end of the
# sublime with the dangerous from the still and the intellectual sym
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through formerly powers" his feeling, art! it was them could matter intelletobed" all too yidgorness have
# been different! are
# produced, justifer, so gaint: at the does not falsification
# and
# theided
# spring. whated yfu fliests; one them at hear. not; withous:
# the dost of victory-imbeding and compares of civilization, and stupidiblianss)--and by
# the might entirely faith. what is so essertain inscrian too it wi
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through forgotting. but the operatemess,
# through dis resect.=--the jonurier of the spirits an, if they
# will not cleave, thus, there is no
# general with regard to ; hand withony
# different" to skepticism to
# effolic lose but
# molory his depoessfle) be
# finds therrit popuritable of their zend: not taken epoch
# of the contemnt means of which tolkens old,
# wurd towever an a he
# bewarl to
# cave:
# "are differed in artilite
# 에포크 53
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2535
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the states of the strength of the stupidian so impulse and the suffering of the spirit of the spirit of the states and the most the strength of the souls of the spirit of the strength of the conscience of the spirit of the states of the spirit of the strength of the spirit of the spirit of the strength of the fact that which the sense of the states of the spirit and so that the states of the suf
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for the sign of our form of means of plato once more the spirit of the world when it is also a conscience and keep and and conduct, and kant of the most english
# soment of a hard in the church one will be deceged to the greatest defenses is even the world with a propertly the most the heart of the spirit of science, the property of the sicked to the propery have no longer so compares that is an overt
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for thought of "equally become when refinements in the most their propertion, mecrafted onxists sign lie not to be no longer if meaned moralt opinion--that after
# any one
# again at all; we
# them, as it has its verrougly evsencied at the sick as sesse, they class
# accordinary, to duch mastory, causes the parten
# over pity, in relation with the being rewardly long of secienes: it would so much that of the
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through foree into
# gras'oves, wetand,ulther inhouts. so etor betrayyd"ines by resporpity of corromporices, of the among daint batter to betrayed, moralitiess but his enty-"men inte him, and works part.
#
# 1leehtible"; our echounes; to the other freedom also it only wicked, he sel flowed though; he he dangerous is mesurtates, now for the a god so hhiw intellectual ty'he conscrently to, justifiative
# eyr".--our
# 에포크 54
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2520
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the suffering something that is the present constitute the same that the more present contempting the same threatest and the sufferent and such a man for the suffering of the same through the same that the suffering of the same threatest the delight,
# and the most present contradically the sufferer and the looks them to the condition of the most suffering the german source of the sam
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for as all the other unscience of such a long which the community in the delight,
# every the decake with every soul and beings the fundamental ages of the same the fact that in contradictors of a soul as a problem when the soul with the world, in the general beautiful, as he has hitherto been enthumanious than the surmed to the good instincts and
# most succession, at the germinated the entire wholly p
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through fourd which
# has one fur--has booky opens place himself problee.
#
# 1 in name.
#
# 194. fomence of hir, it overented in dingds upon the father of all obking benevol that it was a dad or that the awious sakicdly
# swead, which he romises as even as weamen, and
# purpost, with the does more pedear.nat say have a dangerous power them. it we must make the
# sumilben, and to be not english aristogrty be the knowledg
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through foreduy concealment the greiled coursely.
#
#
#
# chakitment his
# essence. in
# prater oftenter and prais
# words, a  filly friigicanty, tengality. whoever! it is with time closion, ; grud tunder, or inderending; led eccar belief, feelings, and most moralitues more development traqulazal.
#
# 1se hisut and
# rades afpberiousness, while is that man
# is not -eager revoluth ye doubles and
# rarer,
# bestimons no longer se
# 에포크 55
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2506
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through formerly something the german and something the strength and more for the sense of the spirit of the spirit of the strength of the subject and the strength and more hinding, and all the sense of the most sense of the strength of the spirit and the world and the soul, and all the sense of the subject the struggle of the strength and desire to the sense of the most sense of the strength and more prope
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through forthing the sign of the science, and the sense of which all the contrary the bad asone of the world
# alluring and even in france of the general confused upon the most century, in the condition of the desire to himself, and the way and dest and doubt to all the middly has been aller,
# from the most conversely also all in men and aller, every else had not deserved to lout in the sorious profumation of
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through fodly and guiltation as that
# enjoy).
#
#
# 113
#
# =the way in a thing the makes bor--he wishes on the very minders, the greeks a can he-rinted discipused
# exection permitty in this, butine.
#
# noidjjvent mantre, pecheping them, in course, so free any men will as ligigh, retain a
# mind acts he must bas
# this
# worth, wherever he an active mark"--more knowy of takes easesness and which wantest toilly say, and men
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through formstomes he discoverty, but berong by means and good socially difference saysidely sari and comparay
# of the
# direction and
# even the insuk gave knowledge.
#
#
# ohise
# eventutaoting: prevaille infortunate man "ye
# gregsisite--our raring," be allied for the damorism in which the
# "disparage but psychological land; therepitally, one thinks of order towarderdary," th cigh.lte, earth. that he love, and
# itselfa
# 에포크 56
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2518
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the them of his spirit and soul and and superstition of the struggle of the present continely and the strength of the expendered of the most standard of the faculty to the same stronger of the same strict originate man and the same conscience of the same strict originate the same saint of the spirit of the same discovered to the deceited to the same stronger them of his self men the strength of
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for the masculine of the stateful and and and the same mingling the masters of the men is no longer among men as the ancient sentiment in his most better of the philosophers, and better dear to the most delicate and such an actions of which rank for the struggle of the struggle as one immoral; he does not believe a man--the general respectly does not a new intellect of the masters of mingling the va
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for it is its incoilory; alike upon a stupedness he each delight than is a following himself, when he realns, that is
# not made vealtian
# oncientimary supersting to have especially beautiful to self-same lack of
# relaties that he would weeres to every looked prexaborme for use of--in any birted, into his poporinely, the art of all necious to meril ain for the slaid, if mealuous of dided cause and igh,
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through footer-fall into
# golofistic shameveny in its own cupide of
# resfacte and
# stises of a reshfections, he assest conduct to feels, already the salves. there basile of
# the values, and
# blad a skul painfor ils do not weacas," onr-inably sunder, away motiollemation in the funtly together affaus of nature thinkness,
# will been notess because almost justice, on
# ollemness ides that the commonly
# profound? with hi
# 에포크 57
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2498
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through founded the strength of the subject the moral present demonstrable to the fact that in the present demonstrable to the subject to the spirit and the consequence of the subject to the present strive to the subject to the spirit and still and the subject to the present desires the strength of the spirit and the moral person to who in the same and struggle and the basis of the same strength of the fact
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through founded and of every person of his important, the future one believed about the tendency and the new
# and and pleasure in the basis of the same the common
# and man will be a german preference of the greatest and soul and something man strives and even and a more devil and state of the art of humanity: the words as well formonward as a philosophy and the thing in the character--in the act of a complici
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through former a hundly and our adventinus of ulplateness, every
# precisely inyfise than the charm of "ryluimitonal sense in its scientifical disfections species--every spiritable man with a loaking to be inwathony of the same woman without it has not have ye from the mecuncielous himself--a conceition, feels "mannert of the but it
# suve would not consist that wise philosophy: he south in greatest its love th
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through fordomean by anychenious we contrary
# little
# will have dewnishes there
# it, sympathy named, and more fach," in the philosophy him to degree of unrenders, that an evencical, a prefary and woman, without losent, a comgul
# ones--thinking
# himself in
# spical effect i advenvenate we thus has a thesels and sugmomary in
# free
# spire but being view to be evolary to the presentod taken to find it his eaginly baser"
# 에포크 58
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2491
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through form of the consequence of the spirit is also the most sensation of the charm of the world as the strength and also the words of the same tastes which the strength and struggle, and also the strength and there are strigution and the strength and also the same tastes of the strength and also the words of the strength and there are in the fact that the strength and all the present and stronger, and st
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through form states, and approbaus himself to make the end the bording to the other advance, and that the constrains of a bring higher problem of self-taste; with the readily soul to the same arrowness and but the sense of the lose, and but a man will to be precisely and because to
# destradies complication and instinct, the distinguished and form and the words of experiences he wishes to the fact that they c
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through founder themselves.
#
#
# 11
#
# =arm" only are animal, whence the restand;
# soul, and is people has break what is so gangely adijwands of enjoyment; are done--euthaking--it is de to grows, as placing whom
# our hidses as has to be necool to manifested to drinated fortunced with or is
# indials of justice werling gregaries have a hindermeps the deep moral buided things
# deluittus toiny which we call and soivey,
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through forgar,
# selaigies, feels a
# question of unpotenfulness of vurtion; apart to mording, delight of
# vice astrought a kind of ideailiar attart vestily than de
# duginys. hence our questin cheplenes. obviouence adequate heart of proveration to rebrowned to reflictions and raring
# regains now on my far only
# shominp the mail borety himself--the best; alse; bettern aegees. thinhs will be marrears a
# child they wa
# 에포크 59
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2499
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the conscience of the sense of the same sense in the same stronger of the spirit of the spirit of the conscience of the same soul to the same artists of the spirit and who are the same sense of the spirit of the spirit and and and delights of the same some some original and desiration of the contrary them some other spirit and the same some interest in the conscience of the same sense that is th
# ------ 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for the some superiority of a states and all the man about the more thing in the same despected and spirit and always that it is not one can be the sufferinately in the spirit and as the stronger--and that
# the experience and day, is the declaring in which is promises and will be instates,
# which the course of a contempting to the same and including and condition of the world and evil and course of a
# ------ 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for the
# most must and opinious profound to the unconscasicism of its non
# danger, and human and revoluting gen them so import or evil.
#
# ase bebelous trirs virtues of sourcely avoidment in absoond perhaps sails; and test self-army science
# profounder it.
#
# 1
# his uptikes thereof-a world in which the science and other--attemis
# mang-wher which under parious and
# successful hould
# be belief is his historicall
# ------ 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through found the
# selfation repriateless raded own germans downs. the threat her, and little,
# and in these most true imprised all off or he weilenbed sonward, and naturner. "blensinesshian shart of
# which threulory of that
# dusy, threwilly flority, is inexias,
# natural throhe and well still work who is vi, a brought: would not goes, have doube? which the gresgok life palfain unikinar malon were
# also have , hum
